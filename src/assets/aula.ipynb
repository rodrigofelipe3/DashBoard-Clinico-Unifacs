# %%
import pandas as pd

df = pd.read_csv('dados_exames_jan_a_abr_2024.csv',sep=';',encoding="cp1252",low_memory=False)
df.head()
# Out:
#      PRONT        REG SEXO      BAIRRO                  CIDADE        DATA  \
# 0   45.158    258.812    F  ASA BRANCA        FEIRA DE SANTANA  01/01/2024
# 1  528.187    258.695    F  ZONA RURAL                 ANGUERA  01/01/2024
# 2  527.092    258.239    M  ZONA RURAL  SAO GONCALO DOS CAMPOS  01/01/2024
# 3  527.092    258.239    M  ZONA RURAL  SAO GONCALO DOS CAMPOS  01/01/2024
# 4   69.986  1.982.297    F     MUCHILA        FEIRA DE SANTANA  01/02/2024
#
#   ATENDIMENTO     CLINICA RADIOLOGIA  ATO  QTDE EXAME  \
# 0     Interno  Emergencia        USG   24     1   UQD
# 1     Interno  Emergencia     RAIO-X   16     1    T1
# 2     Interno  Emergencia        USG   24     1  UTRA
# 3     Interno  Emergencia        USG   24     1  UTRA
# 4     Externo  Radiologia        USG   24     1  USAT
#
#                                                 NOME RN  RNS     SITUACAO
# 0          ULTRASSONOGRAFIA DE QUADRIL (ARTICULA?AO)  T    1  Em Adamento
# 1                                        TORAX: P.A.  F    0  Em Adamento
# 2                     ULTRASONOGRAFIA TRANSFONTANELA  F    0  Em Adamento
# 3                     ULTRASONOGRAFIA TRANSFONTANELA  F    0  Em Adamento
# 4  ABDOMEN TOTAL (ABDOMEN SUPERIOR - RINS-RETROPE...  F    0  Em Adamento

# %%
#df.info()
df.isna().sum()
# Out:
# PRONT          0
# REG            0
# SEXO           0
# BAIRRO         0
# CIDADE         0
# DATA           0
# ATENDIMENTO    0
# CLINICA        0
# RADIOLOGIA     0
# ATO            0
# QTDE           0
# EXAME          0
# NOME           0
# RN             0
# RNS            0
# SITUACAO       0
# dtype: int64

# %%
df = df.dropna(how='all',axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63863 entries, 0 to 63862
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRONT        63863 non-null  object
#  1   REG          63863 non-null  object
#  2   SEXO         63863 non-null  object
#  3   BAIRRO       63863 non-null  object
#  4   CIDADE       63863 non-null  object
#  5   DATA         63863 non-null  object
#  6   ATENDIMENTO  63863 non-null  object
#  7   CLINICA      63863 non-null  object
#  8   RADIOLOGIA   63863 non-null  object
#  9   ATO          63863 non-null  int64
#  10  QTDE         63863 non-null  int64
#  11  EXAME        63863 non-null  object
#  12  NOME         63863 non-null  object
#  13  RN           63863 non-null  object
#  14  RNS          63863 non-null  int64
#  15  SITUACAO     63863 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 7.8+ MB

# %%
df['DATA'] = pd.to_datetime(df.DATA,errors = 'coerce')
df.count()
df.info()
df_novo = df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df['DATA'] = pd.to_datetime(df.DATA,errors = 'coerce')
#       2 df.count()
#       3 df.info()
#
# NameError: name 'pd' is not defined

# %%
df_novo = df_novo.dropna(axis=0)

# %%
df_novo
# Out:
# Empty DataFrame
# Columns: [PRONT, REG, SEXO, BAIRRO, CIDADE, IBGE, DT, DATA, ATENDIMENTO, CLINICA, RADIOLOGIA, ATO, QTDE, EXAME, NOME, RN, RNS, SITUACAO, Unnamed: 18]
# Index: []
